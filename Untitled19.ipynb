# %% [markdown]
# <a href="https://colab.research.google.com/github/alaeddine-hash/GL-MoyenneApp/blob/master/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !wget -q https://archive.apache.org/dist/spark/spark-3.3.1/spark-3.3.1-bin-hadoop3.tgz

# %%
# !tar xf spark-3.3.1-bin-hadoop3.tgz

# %%
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.3.1-bin-hadoop3"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.getOrCreate()

# %%
sc = spark.sparkContext

# %%
rdd1 = sc.textFile('/content/Shakespeare.txt')

# %%
rdd1.collect()
# Out:
# ['by William Shakespeare',
#  '',
#  'From fairest creatures we desire increase,',
#  "That thereby beauty's rose might never die,",
#  'But as the riper should by time decease,',
#  'His tender heir might bear his memory:',
#  'But thou contracted to thine own bright eyes,',
#  "Feed'st thy light's flame with self-substantial fuel,",
#  'Making a famine where abundance lies,',
#  'Thy self thy foe, to thy sweet self too cruel:',
#  "Thou that art now the world's fresh ornament,",
#  'And only herald to the gaudy spring,',
#  'Within thine own bud buriest thy content,',
#  "And tender churl mak'st waste in niggarding:",
#  'Pity the world, or else this glutton be,',
#  "To eat the world's due, by the grave and thee.",
#  '',
#  'When forty winters shall besiege thy brow,',
#  "And dig deep trenches in thy beauty's field,",
#  "Thy youth's proud livery so gazed on now,",
#  'Will be a tattered weed of small worth held:  ',
#  'Then being asked, where all thy beauty lies,',
# ...

# %%
rdd1.count()
# Out:
# 2467

# %%
words = rdd1.flatMap(lambda line: line.split())

words.collect()
# Out:
# ['by',
#  'William',
#  'Shakespeare',
#  'From',
#  'fairest',
#  'creatures',
#  'we',
#  'desire',
#  'increase,',
#  'That',
#  'thereby',
#  "beauty's",
#  'rose',
#  'might',
#  'never',
#  'die,',
#  'But',
#  'as',
#  'the',
#  'riper',
#  'should',
#  'by',
#  'time',
#  'decease,',
#  'His',
#  'tender',
#  'heir',
#  'might',
#  'bear',
#  'his',
#  'memory:',
#  'But',
#  'thou',
#  'contracted',
#  'to',
#  'thine',
#  'own',
#  'bright',
#  'eyes,',
#  "Feed'st",
#  'thy',
#  "light's",
#  'flame',
#  'with',
#  'self-substantial',
#  'fuel,',
#  'Making',
#  'a',
#  'famine',
#  'where',
#  'abundance',
#  'lies,',
#  'Thy',
#  'self',
#  'thy',
#  'foe,',
#  'to',
#  'thy',
#  'sweet',
#  'self',
#  'too',
#  'cruel:',
#  'Thou',
#  'that',
#  'art',
#  'now',
#  'the',
#  "world's",
#  'fresh',
#  'ornament,',
#  'And',
#  'only',
#  'herald',
#  'to',
#  'the',
#  'gaudy',
#  'spring,',
#  'Within',
#  'thine',
#  'own',
#  'bud',
#  'buriest',
#  'thy',
# ...

# %%
# Attribution de la valeur 1 à chaque mot dans l'RDD "words" en utilisant la méthode "map"
word_counts = words.map(lambda word: (word, 1))

# Affichage des 10 premiers éléments de l'RDD "word_counts"
word_counts.collect()
# Out:
# [('by', 1),
#  ('William', 1),
#  ('Shakespeare', 1),
#  ('From', 1),
#  ('fairest', 1),
#  ('creatures', 1),
#  ('we', 1),
#  ('desire', 1),
#  ('increase,', 1),
#  ('That', 1),
#  ('thereby', 1),
#  ("beauty's", 1),
#  ('rose', 1),
#  ('might', 1),
#  ('never', 1),
#  ('die,', 1),
#  ('But', 1),
#  ('as', 1),
#  ('the', 1),
#  ('riper', 1),
#  ('should', 1),
#  ('by', 1),
#  ('time', 1),
#  ('decease,', 1),
#  ('His', 1),
#  ('tender', 1),
#  ('heir', 1),
#  ('might', 1),
#  ('bear', 1),
#  ('his', 1),
#  ('memory:', 1),
#  ('But', 1),
#  ('thou', 1),
#  ('contracted', 1),
#  ('to', 1),
#  ('thine', 1),
#  ('own', 1),
#  ('bright', 1),
#  ('eyes,', 1),
#  ("Feed'st", 1),
#  ('thy', 1),
#  ("light's", 1),
#  ('flame', 1),
#  ('with', 1),
#  ('self-substantial', 1),
#  ('fuel,', 1),
#  ('Making', 1),
#  ('a', 1),
#  ('famine', 1),
#  ('where', 1),
#  ('abundance', 1),
#  ('lies,', 1),
#  ('Thy', 1),
#  ('self', 1),
#  ('thy', 1),
#  ('foe,', 1),
#  ('to', 1),
#  ('thy', 1),
# ...

# %%
# Regroupement des valeurs de comptage de chaque mot en utilisant la méthode "reduceByKey"
word_counts = word_counts.reduceByKey(lambda a, b: a + b)

# Affichage des 10 premiers éléments de l'RDD "word_counts"
word_counts.collect()
# Out:
# [('Shakespeare', 1),
#  ('fairest', 5),
#  ('creatures', 2),
#  ('we', 14),
#  ('increase,', 4),
#  ('That', 83),
#  ('thereby', 1),
#  ("beauty's", 17),
#  ('rose', 3),
#  ('never', 13),
#  ('But', 89),
#  ('as', 81),
#  ('riper', 2),
#  ('tender', 7),
#  ('heir', 1),
#  ('bear', 7),
#  ('his', 102),
#  ('memory:', 1),
#  ('thou', 205),
#  ('thine', 30),
#  ('own', 28),
#  ('bright', 7),
#  ('thy', 258),
#  ("light's", 1),
#  ('flame', 3),
#  ('fuel,', 1),
#  ('Making', 6),
#  ('famine', 1),
#  ('where', 26),
#  ('abundance', 4),
#  ('self', 67),
#  ('foe,', 1),
#  ('sweet', 43),
#  ('cruel:', 1),
#  ('Thou', 25),
#  ('now', 28),
#  ("world's", 5),
#  ('ornament,', 2),
#  ('And', 242),
#  ('only', 5),
#  ('herald', 1),
#  ('Within', 5),
#  ('churl', 2),
#  ("mak'st", 2),
#  ('in', 286),
#  ('niggarding:', 1),
#  ('Pity', 3),
#  ('world,', 4),
#  ('this', 84),
#  ('due,', 3),
#  ('grave', 2),
#  ('When', 57),
#  ('forty', 1),
#  ('winters', 2),
#  ('besiege', 2),
#  ('dig', 1),
# ...

# %%
# Écriture du résultat dans un fichier texte sur le disque en utilisant la méthode "saveAsTextFile"
word_counts.saveAsTextFile("chemin/vers/le/fichier_de_sortie_sans_colescpace().txt")

# %%
df = spark.read.format("csv").load("/content/daily-weather (1).csv", header = True, inferSchema=True)

# %%
df.columns
# Out:
# ['number',
#  'air_pressure_9am',
#  'air_temp_9am',
#  'avg_wind_direction_9am',
#  'avg_wind_speed_9am',
#  'max_wind_direction_9am',
#  'max_wind_speed_9am',
#  'rain_accumulation_9am',
#  'rain_duration_9am',
#  'relative_humidity_9am',
#  'relative_humidity_3pm']

# %%
# Visualisation des colonnes avec la méthode ".columns"
print("Colonnes :")
print(df.columns)

# Visualisation des types des colonnes avec la méthode ".printSchema()"
print("\nSchéma :")
df.printSchema()

# Affichage des 5 premiers éléments avec la méthode ".head(5)"
print("\n5 premiers éléments :")
print(df.head(5))
# Out:
# Colonnes :
# ['number', 'air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am', 'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am', 'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am', 'relative_humidity_3pm']
#
# Schéma :
# root
#  |-- number: integer (nullable = true)
#  |-- air_pressure_9am: double (nullable = true)
#  |-- air_temp_9am: double (nullable = true)
#  |-- avg_wind_direction_9am: double (nullable = true)
#  |-- avg_wind_speed_9am: double (nullable = true)
#  |-- max_wind_direction_9am: double (nullable = true)
#  |-- max_wind_speed_9am: double (nullable = true)
#  |-- rain_accumulation_9am: double (nullable = true)
#  |-- rain_duration_9am: double (nullable = true)
#  |-- relative_humidity_9am: double (nullable = true)
#  |-- relative_humidity_3pm: double (nullable = true)
#
#
# 5 premiers éléments :
# ...

# %%
df.describe().toPandas().transpose()
# Out:
#                             0                    1                   2  \
# summary                 count                 mean              stddev
# number                   1095                547.0  316.24357700987383
# air_pressure_9am         1092    918.8825513138094   3.184161180386833
# air_temp_9am             1090    64.93300141287072  11.175514003175877
# avg_wind_direction_9am   1091    142.2355107005759   69.13785928889189
# avg_wind_speed_9am       1092     5.50828424225493  4.5528134655317185
# max_wind_direction_9am   1092   148.95351796516923   67.23801294602953
# max_wind_speed_9am       1091    7.019513529175272   5.598209170780958
# rain_accumulation_9am    1089  0.20307895225211126  1.5939521253574893
# rain_duration_9am        1092    294.1080522756142  1598.0787786601481
# relative_humidity_9am    1095    34.24140205923536  25.472066802250055
# relative_humidity_3pm    1095    35.34472714825898  22.524079453587273
#
# ...

# %%
Df1 = df.withColumn("ratio", df['rain_duration_9am'] / df['rain_accumulation_9am'])

# %%
Df1.select('ratio').show()
# Out:
# +------------------+
# |             ratio|
# +------------------+
# |              null|
# |              null|
# |              null|
# |              null|
# |1655.0561797755388|
# | 8499.999999814461|
# |              null|
# |              null|
# |              null|
# |              null|
# |              null|
# | 3218.181818182084|
# |              null|
# |              null|
# |              null|
# |              null|
# |              null|
# |              null|
# |              null|
# |              null|
# +------------------+
# only showing top 20 rows

# %%
# Tri du DataFrame en ordre décroissant de la colonne "rain_duration_9am" avec la méthode "orderBy()"
from pyspark.sql.functions import desc
df_max_rain_duration_9am = Df1.orderBy(desc("rain_duration_9am"))
# Affichage de la première ligne avec la méthode "head()"
max_rain_duration_9am = df_max_rain_duration_9am.head(1)

# Affichage du maximum de rain_duration_9am
print("Le maximum de rain_duration_9am est :", max_rain_duration_9am[0]["rain_duration_9am"])
# Out:
# Le maximum de rain_duration_9am est : 17704.0

# %%
# Calcul de la moyenne de la colonne "rain_accumulation_9am" avec la méthode "agg()"
mean_rain_accumulation_9am = Df1.agg({"rain_accumulation_9am": "mean"}).collect()[0][0]

# Affichage de la moyenne
print("La moyenne de rain_accumulation_9am est :", mean_rain_accumulation_9am)
# Out:
# La moyenne de rain_accumulation_9am est : 0.20307895225211126

# %%
# Calcul du maximum de la colonne "rain_duration_9am" avec la méthode "agg()"
max_rain_duration_9am = Df1.agg({"rain_duration_9am": "max"}).collect()[0][0]

# Calcul du minimum de la colonne "rain_duration_9am" avec la méthode "agg()"
min_rain_duration_9am = Df1.agg({"rain_duration_9am": "min"}).collect()[0][0]

# Affichage du maximum et du minimum
print("Le maximum de rain_duration_9am est :", max_rain_duration_9am)
print("Le minimum de rain_duration_9am est :", min_rain_duration_9am)
# Out:
# Le maximum de rain_duration_9am est : 17704.0
# Le minimum de rain_duration_9am est : 0.0

# %%
# Filtrage des lignes où la colonne "air_temp_9am" est supérieure à 70 avec la méthode "filter()"
filtered_df = Df1.filter(df['air_temp_9am'] > 70)

# Comptage du nombre de lignes résultantes avec la méthode "count()"
count = filtered_df.count()

# Affichage du résultat
print("Le nombre de fois où air_temp_9am est > 70 est :", count)
# Out:
# Le nombre de fois où air_temp_9am est > 70 est : 384

# %%
df2=df.na.drop(subset=['air_pressure_9am'])

# %%
# Calcul de la corrélation entre les colonnes "rain_accumulation_9am" et "rain_duration_9am" avec la méthode "corr()"
correlation = df2.corr("rain_accumulation_9am", "rain_duration_9am")

# Affichage du résultat
print("La corrélation entre rain_accumulation_9am et rain_duration_9am est :", correlation)
# Out:
# La corrélation entre rain_accumulation_9am et rain_duration_9am est : 0.7298253479609021

# %%
from pyspark.sql import functions

# Chargement de la fonction "avg()"
avg_function = functions.avg

# %%
inputeDf = df

# %%
for x in inputeDf.columns :
  meanValue = inputeDf.agg(avg_function(x)).first()[0]
  print(x, meanValue)
  inputeDf = inputeDf.na.fill(meanValue,[x])
# Out:
# number 547.0
# air_pressure_9am 918.8825513138094
# air_temp_9am 64.93300141287072
# avg_wind_direction_9am 142.2355107005759
# avg_wind_speed_9am 5.50828424225493
# max_wind_direction_9am 148.95351796516923
# max_wind_speed_9am 7.019513529175272
# rain_accumulation_9am 0.20307895225211126
# rain_duration_9am 294.1080522756142
# relative_humidity_9am 34.24140205923536
# relative_humidity_3pm 35.34472714825898
